# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
tf.__version__
import pandas as pd
import tensorflow as tf
df=pd.read_csv('/content/drive/MyDrive/zomato.csv')
df=df.drop(['phone','dish_liked','rate','menu_item'],axis=1)
df.drop_duplicates(inplace=True)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df.head(5)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  votes      location            rest_type  \
# 0          Yes        Yes    775  Banashankari        Casual Dining
# 1          Yes         No    787  Banashankari        Casual Dining
# 2          Yes         No    918  Banashankari  Cafe, Casual Dining
# 3           No         No     88  Banashankari          Quick Bites
# 4           No         No    166  Basavanagudi        Casual Dining
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list listed_in(type)  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...          Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...          Buffet
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...          Buffet
# 3  [('Rated 4.0', "RATED\n  Great food and proper...          Buffet
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# 4    Banashankari

# %%
df.isna().sum()

df.dropna()
df.isna().sum()
# Out:
# url                              0
# address                          0
# name                             0
# online_order                     0
# book_table                       0
# votes                            0
# location                        21
# rest_type                      227
# cuisines                        45
# approx_cost(for two people)    346
# reviews_list                     0
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
import re
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].astype(str).apply(lambda x: re.sub(',', '', x)).astype(float).dropna()
df.dropna().isna().sum()
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table  votes      location      rest_type  \
# 0          Yes        Yes    775  Banashankari  Casual Dining
# 1          Yes         No    787  Banashankari  Casual Dining
#
#                          cuisines  approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                        800.0
# 1     Chinese, North Indian, Thai                        800.0
#
#                                         reviews_list listed_in(type)  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...          Buffet
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari

# %%
df=df.rename(columns={'approx_cost(for two people)': 'cost',
           'listed_in(type)': 'type',
           'listed_in(city)': 'city'
           })
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table  votes      location      rest_type  \
# 0          Yes        Yes    775  Banashankari  Casual Dining
# 1          Yes         No    787  Banashankari  Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
#
#                                         reviews_list    type          city
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...  Buffet  Banashankari
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...  Buffet  Banashankari

# %%
import matplotlib as plt
import seaborn as sns
#df['type'].value_counts().plot(kind='bar') #online_order
g = sns.catplot(data=df, x="online_order", y="cost",col="type",
    kind="bar", height=4, aspect=.6,
    #cmap="coolwarm"
)
plt.rcParams['figure.figsize'] = [10,5]
g.set_axis_labels("", "Cost Rate")
g.set_xticklabels(["YES","NO"])

g.set_titles("{col_name} {col_var}")
g.set(ylim=(0, 1500))
g.despine(left=True)

# %% [markdown]
# ##workin on the online delivery

# %%
order_online=df[df.online_order=='Yes']
order_online=order_online.drop('online_order',axis=1)
print(order_online)
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 5      https://www.zomato.com/bangalore/timepass-dinn...
# 7      https://www.zomato.com/bangalore/onesta-banash...
# ...                                                  ...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
# 51701  https://www.zomato.com/bangalore/the-beer-cafe...
# 51703  https://www.zomato.com/bangalore/olivers-pub-d...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 5      37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# ...                                                  ...
# 51697  Level 2, Phoenix Marketcity, Mahadevpura, Whit...
# 51699  S-10, Level 2, Phoenix Market City, Whitefield...
# 51701  Unit 4A - 4B, Upper Ground Floor, VR Bengaluru...
# 51703  ITPL Ascendas Park Square Mall, ITPL, First Fl...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
#
#                            name book_table  votes      location  \
# 0                         Jalsa        Yes    775  Banashankari
# 1                Spice Elephant         No    787  Banashankari
# 2               San Churro Cafe         No    918  Banashankari
# 5               Timepass Dinner         No    286  Basavanagudi
# 7                        Onesta        Yes   2556  Banashankari
# ...                         ...        ...    ...           ...
# 51697  Shizusan Shophouse & Bar        Yes   1313    Whitefield
# 51699        Harry's Bar + Cafe        Yes   1218    Whitefield
# 51701             The Beer Cafe        Yes    673    Whitefield
# 51703      Oliver's Pub & Diner        Yes    548    Whitefield
# 51705        Izakaya Gastro Pub        Yes    128    Whitefield
#
#                  rest_type                                           cuisines  \
# 0            Casual Dining                     North Indian, Mughlai, Chinese
# 1            Casual Dining                        Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                             Cafe, Mexican, Italian
# 5            Casual Dining                                       North Indian
# 7      Casual Dining, Cafe                               Pizza, Cafe, Italian
# ...                    ...                                                ...
# 51697   Casual Dining, Bar  Asian, Japanese, Vietnamese, Korean, Chinese, ...
# 51699                  Pub                           Asian, American, Mexican
# 51701                  Pub        Finger Food, North Indian, Chinese, Italian
# 51703   Pub, Casual Dining  Finger Food, American, Continental, Burger, Pizza
# 51705   Bar, Casual Dining           North Indian, Continental, Mediterranean
#
#          cost                                       reviews_list  \
# 0       800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1       800.0  [('Rated 4.0', 'RATED\n  Had been here for din...
# 2       800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...
# 5       600.0  [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...
# 7       600.0  [('Rated 5.0', 'RATED\n  I personally really l...
# ...       ...                                                ...
# 51697  1800.0  [('Rated 3.0', 'RATED\n  Wanted to try this pl...
# 51699  1200.0  [('Rated 4.0', 'RATED\n  The first thing that ...
# 51701  1400.0  [('Rated 2.0', "RATED\n  We went out to this p...
# 51703  1500.0  [('Rated 4.0', "RATED\n  I had :-\n\n1. Italia...
# 51705  1200.0  [('Rated 3.0', "RATED\n  Nice place to hangout...
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 5             Buffet  Banashankari
# 7              Cafes  Banashankari
# ...              ...           ...
# 51697  Pubs and bars    Whitefield
# 51699  Pubs and bars    Whitefield
# 51701  Pubs and bars    Whitefield
# 51703  Pubs and bars    Whitefield
# 51705  Pubs and bars    Whitefield
#
# [30444 rows x 12 columns]

# %%
import matplotlib as plt
v=(order_online.cuisines.str.split(',',expand=True).stack().value_counts())
#sns.barplot(y=v.index,x=v.values,hue=v)
plt.rcParams['figure.figsize'] = [10,5]
((v/v.sum()*100)>1).sum() #head(26)
v.rename(index='count')
# Out:
#  Chinese         7578
# North Indian     7182
#  North Indian    5236
#  Fast Food       3505
# Cafe             2599
#                  ...
#  Grill              2
#  Pan Asian          1
# Bar Food            1
#  Raw Meats          1
#  Hot dogs           1
# Name: count, Length: 174, dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import plotly.express as px

# Sample data preparation
# Replace this with your data import if needed

# Group data by location and calculate the sum of votes for each cost range
order_online['cost_range'] = pd.cut(order_online['cost'], bins=[0, 500, 1000, 1500, 2000, order_online['cost'].max()], labels=['0-500', '500-1000', '1000-1500', '1500-2000', '2000+']).sort_values()
grouped_data = order_online.groupby(['location', 'cost_range'])['votes'].sum().reset_index()

# Create a stacked bar chart
fig = px.bar(grouped_data, x='location', y='votes', color='cost_range', title="Stacked Bar Chart of Votes by Location and Cost Range")
fig.show()
# Out:
# <ipython-input-12-6020ea30a61b>:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = order_online.groupby(['location', 'cost_range'])['votes'].sum().reset_index()
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5aee3ab2-b548-468c-892a-bda25b3066e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aee3ab2-b548-468c-892a-bda25b3066e4")) {                    Plotly.newPlot(                        "5aee3ab2-b548-468c-892a-bda25b3066e4",                        [{"alignmentgroup":"True","hovertemplate":"cost_range=0-500\u003cbr\u003elocation=%{x}\u003cbr\u003evotes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-500","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0-500","offsetgroup":"0-500","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Banashankari","Banaswadi","Bannerghatta Road","Basavanagudi","Basaveshwara Nagar","Bellandur","Bommanahalli","Brigade Road","Brookefield","CV Raman Nagar","Central Bangalore","Church Street","City Market","Commercial Street","Cunningham Road","Domlur","East Bangalore","Ejipura","Electronic City","Frazer Town","HBR Layout","HSR","Hebbal","Hennur","Hosur Road","ITPL Main Road, Whitefield","Indiranagar","Infantry Road","JP Nagar","Jalahalli","Jayanagar","Jeevan Bhima Nagar","KR Puram","Kaggadasapura","Kalyan Nagar","Kammanahalli","Kanakapura Road","Kengeri","Koramangala","Koramangala 1st Block","Koramangala 2nd Block","Koramangala 3rd Block","Koramangala 4th Block","Koramangala 5th Block","Koramangala 6th Block","Koramangala 7th Block","Koramangala 8th Block","Kumaraswamy Layout","Langford Town","Lavelle Road","MG Road","Magadi Road","Majestic","Malleshwaram","Marathahalli","Mysore Road","Nagarbhavi","Nagawara","New BEL Road","North Bangalore","Old Airport Road","Old Madras Road","RT Nagar","Race Course Road","Rajajinagar","Rajarajeshwari Nagar","Rammurthy Nagar","Residency Road","Richmond Road","Sadashiv Nagar","Sahakara Nagar","Sanjay Nagar","Sarjapur Road","Seshadripuram","Shanti Nagar","Shivajinagar","South Bangalore","St. Marks Road","Thippasandra","Ulsoor","Uttarahalli","Varthur Main Road, Whitefield","Vasanth Nagar","Vijay Nagar","West Bangalore","Whitefield","Wilson Garden","Yelahanka","Yeshwantpur"],"xaxis":"x","y":[250428,38480,14531,48444,39313,4383,46766,3590,41290,33686,1662,1150,8110,457,6160,6097,17258,2391,14377,35970,20903,2037,133354,158,4374,7370,3927,130236,196,70149,362,127553,31083,161,4481,25379,22614,409,308,5602,60348,1199,6307,43135,210347,84872,62058,13072,12240,126,12560,8819,538,294,58097,77206,435,10,9851,29110,1606,15398,554,2425,5074,20225,0,538,19310,13968,3070,2283,2372,35555,7828,11999,961,2495,10235,6577,21034,358,4804,10039,5514,1072,57758,4070,176,5340],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"cost_range=500-1000\u003cbr\u003elocation=%{x}\u003cbr\u003evotes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"500-1000","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"500-1000","offsetgroup":"500-1000","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Banashankari","Banaswadi","Bannerghatta Road","Basavanagudi","Basaveshwara Nagar","Bellandur","Bommanahalli","Brigade Road","Brookefield","CV Raman Nagar","Central Bangalore","Church Street","City Market","Commercial Street","Cunningham Road","Domlur","East Bangalore","Ejipura","Electronic City","Frazer Town","HBR Layout","HSR","Hebbal","Hennur","Hosur Road","ITPL Main Road, Whitefield","Indiranagar","Infantry Road","JP Nagar","Jalahalli","Jayanagar","Jeevan Bhima Nagar","KR Puram","Kaggadasapura","Kalyan Nagar","Kammanahalli","Kanakapura Road","Kengeri","Koramangala","Koramangala 1st Block","Koramangala 2nd Block","Koramangala 3rd Block","Koramangala 4th Block","Koramangala 5th Block","Koramangala 6th Block","Koramangala 7th Block","Koramangala 8th Block","Kumaraswamy Layout","Langford Town","Lavelle  ...

# %%
# Visualization 4: Interactive Scatter Plot of Cost vs Votes by Location
fig = px.scatter(order_online, x='cost', y='votes', color='location', title="Cost vs Votes by Location")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d7d17405-dd9d-4707-9671-3e11fc490390" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7d17405-dd9d-4707-9671-3e11fc490390")) {                    Plotly.newPlot(                        "d7d17405-dd9d-4707-9671-3e11fc490390",                        [{"hovertemplate":"location=Banashankari\u003cbr\u003ecost=%{x}\u003cbr\u003evotes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Banashankari","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Banashankari","showlegend":true,"x":[800.0,800.0,800.0,600.0,700.0,550.0,500.0,600.0,500.0,800.0,650.0,800.0,700.0,400.0,400.0,500.0,600.0,200.0,500.0,500.0,750.0,500.0,650.0,400.0,600.0,150.0,500.0,800.0,600.0,450.0,300.0,800.0,400.0,500.0,300.0,400.0,300.0,450.0,300.0,500.0,450.0,300.0,400.0,400.0,200.0,250.0,150.0,450.0,700.0,500.0,150.0,400.0,350.0,500.0,200.0,300.0,200.0,400.0,750.0,150.0,500.0,800.0,700.0,550.0,500.0,600.0,300.0,700.0,750.0,250.0,600.0,350.0,200.0,650.0,650.0,600.0,500.0,200.0,800.0,250.0,150.0,1200.0,700.0,800.0,800.0,200.0,800.0,300.0,400.0,250.0,150.0,600.0,100.0,700.0,200.0,400.0,400.0,600.0,250.0,300.0,200.0,400.0,400.0,200.0,250.0,500.0,150.0,300.0,300.0,200.0,300.0,250.0,350.0,600.0,400.0,100.0,200.0,500.0,250.0,400.0,350.0,150.0,250.0,200.0,500.0,100.0,800.0,600.0,300.0,800.0,800.0,300.0,200.0,200.0,300.0,750.0,400.0,500.0,200.0,400.0,150.0,400.0,400.0,800.0,300.0,700.0,500.0,100.0,400.0,350.0,200.0,500.0,400.0,500.0,750.0,1200.0,350.0,600.0,800.0,800.0,800.0,700.0,800.0,550.0,500.0,600.0,500.0,450.0,600.0,800.0,800.0,650.0,900.0,700.0,800.0,700.0,300.0,500.0,400.0,400.0,700.0,700.0,600.0,500.0,600.0,750.0,600.0,800.0,400.0,150.0,500.0,750.0,650.0,300.0,200.0,450.0,200.0,300.0,500.0,150.0,100.0,300.0,300.0,100.0,150.0,250.0,250.0,200.0,500.0,300.0,500.0,300.0,150.0,600.0,400.0,200.0,500.0,200.0,200.0,250.0,400.0,800.0,250.0,250.0,300.0,350.0,400.0,150.0,600.0,300.0,500.0,300.0,250.0,200.0,450.0,200.0,400.0,300.0,250.0,400.0,300.0,200.0,200.0,200.0,250.0,150.0,250.0,400.0,500.0,300.0,800.0,800.0,600.0,700.0,550.0,800.0,650.0,700.0,200.0,400.0,450.0,200.0,450.0,450.0,300.0,800.0,550.0,300.0,200.0,600.0,650.0,200.0,400.0,300.0,750.0,150.0,750.0,500.0,500.0,600.0,100.0,250.0,200.0,600.0,800.0,350.0,250.0,300.0,250.0,150.0,150.0,500.0,250.0,700.0,250.0,900.0,500.0,300.0,400.0,500.0,200.0,800.0,800.0,700.0,500.0,100.0,600.0,450.0,200.0,600.0,150.0,300.0,300.0,800.0,200.0,200.0,700.0,350.0,700.0,150.0,800.0,400.0,600.0,400.0,300.0,600.0,900.0,1200.0,300.0,650.0,200.0,400.0,100.0,300.0,650.0,300.0,150.0,600.0,300.0,750.0,700.0,400.0,800.0,500.0,800.0,800.0,200.0,400.0,200.0,200.0,200.0,750.0,500.0,800.0,200.0,400.0,700.0,350.0,400.0,350.0,800.0,800.0,800.0,600.0,700.0,550.0,600.0,800.0,800.0,750.0,700.0,650.0,800.0,300.0,700.0,750.0,150.0,300.0,500.0,250.0,500.0,400.0,100.0,250.0,200.0,300.0,450.0,800.0,300.0,300.0,400.0,150.0,600.0,200.0,600.0,250.0,200.0,250.0,200.0,200.0,300.0,200.0,400.0,500.0,200.0,500.0,200.0,200.0,200.0,800.0,800.0,800.0,600.0,650.0,700.0,200.0,300.0,800.0,550.0,200.0,600.0,750.0,500.0,250.0,600.0,800.0,250.0,500.0,250.0,250.0,300.0,400.0,200.0,800.0,900.0,700.0,500.0,600.0,450.0,200.0,300.0,300.0,800.0,200.0,200.0,700.0,400.0,400.0,300.0,600.0,1200.0,300.0,600.0,650.0,200.0,350.0,100.0,300.0,600.0,300.0,750.0,600.0,700.0,800.0,800.0,800.0,400.0,200.0,200.0,150.0,500.0,700.0,400.0,800.0,800.0,800.0,600.0,1200.0,650.0,800.0,700.0,750.0,300.0,500.0,600.0,500.0,600.0,200.0,200.0,200.0,300.0,500.0,500.0,700.0,400.0,1200.0,650.0,200.0,300.0,750.0,300.0,300.0,800.0,800.0,800.0,200.0,200.0,200.0,200.0],"xaxis":"x","y":[775,787,918,2556,324,504,402,150,164,918,90,133,144,13,62,180,62,75,506,35,172,415,230,91,16 ...

# %%
import pandas as pd
import plotly.express as px

# Load the data
# Replace 'restaurant_data.csv' with your actual dataset file path
#data = pd.read_csv('restaurant_data.csv')

# Fill NaN values in 'cuisines' column with a placeholder and extract the primary cuisine
order_online['cuisines'] = order_online['cuisines'].fillna('Unknown')
order_online['primary_cuisine'] = order_online['cuisines'].apply(lambda x: x.split(',')[0]).sort_values()

# Count the number of restaurants by primary cuisine and location
cuisine_counts = order_online.groupby(['location', 'primary_cuisine']).size().reset_index(name='count')

# Create a stacked bar chart
fig = px.bar(cuisine_counts, x='location', y='count', color='primary_cuisine',
             title="Count of Restaurants by Cuisine Type and Location",
             labels={'count': 'Number of Cuisine', 'location': 'Location'},
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig.update_layout(barmode='stack', xaxis={'categoryorder': 'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d67bd6f4-dd0a-4f85-9397-3532e6ff34fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d67bd6f4-dd0a-4f85-9397-3532e6ff34fc")) {                    Plotly.newPlot(                        "d67bd6f4-dd0a-4f85-9397-3532e6ff34fc",                        [{"alignmentgroup":"True","hovertemplate":"primary_cuisine=American\u003cbr\u003eLocation=%{x}\u003cbr\u003eNumber of Cuisine=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"American","offsetgroup":"American","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Bannerghatta Road","Bellandur","Brigade Road","Church Street","East Bangalore","Ejipura","Electronic City","Frazer Town","HSR","Indiranagar","JP Nagar","Kalyan Nagar","Kammanahalli","Koramangala 6th Block","Koramangala 7th Block","MG Road","Malleshwaram","Nagawara","New BEL Road","Sarjapur Road","Thippasandra","Ulsoor","Varthur Main Road, Whitefield","Whitefield","Yeshwantpur"],"xaxis":"x","y":[10,20,8,11,30,2,13,3,4,20,20,13,10,9,9,16,17,6,1,2,22,4,37,3,19,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"primary_cuisine=Andhra\u003cbr\u003eLocation=%{x}\u003cbr\u003eNumber of Cuisine=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Andhra","offsetgroup":"Andhra","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Banaswadi","Bannerghatta Road","Basavanagudi","Basaveshwara Nagar","Bellandur","Bommanahalli","Brookefield","CV Raman Nagar","Church Street","Cunningham Road","Domlur","East Bangalore","Electronic City","HSR","Hosur Road","Indiranagar","JP Nagar","Jayanagar","Jeevan Bhima Nagar","Kaggadasapura","Kalyan Nagar","Kammanahalli","Kanakapura Road","Koramangala 4th Block","Koramangala 5th Block","Koramangala 6th Block","Malleshwaram","Marathahalli","Nagawara","New BEL Road","Old Airport Road","Rajajinagar","Sahakara Nagar","Sarjapur Road","Thippasandra","Varthur Main Road, Whitefield","Vijay Nagar","Whitefield","Wilson Garden","Yelahanka","Yeshwantpur"],"xaxis":"x","y":[119,24,23,5,2,22,7,21,2,11,12,11,3,32,59,14,32,20,38,8,2,15,5,2,10,17,9,4,48,13,5,4,12,2,21,4,2,3,57,5,1,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"primary_cuisine=Arabian\u003cbr\u003eLocation=%{x}\u003cbr\u003eNumber of Cuisine=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arabian","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Arabian","offsetgroup":"Arabian","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Banashankari","Banaswadi","Bannerghatta Road","Bellandur","Bommanahalli","Brookefield","East Bangalore","Electronic City","Frazer Town","HSR","JP Nagar","Jayanagar","Jeevan Bhima Nagar","Kalyan Nagar","Kammanahalli","Koramangala 1st Block","Koramangala 5th Block","Koramangala 6th Block","Koramangala 7th Block","Kumaraswamy Layout","Marathahalli","Nagawara","New BEL Road","Old Madras Road","Richmond Road","Sarjapur Road","Thippasandra","Ulsoor","Varthur Main Road, Whitefield","Whitefield"],"xaxis":"x","y":[104,2,8,11,8,1,16,1,9,18,18,5,11,4,8,20,11,34,9,11,1,10,4,2,5,11,14,4,17,7,8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"primary_cuisine=Asian\u003cbr\u003eLocation=%{x}\u003cbr\u003eNumber of Cuisine=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Asian","offsetgroup":"Asian","orientation":"v","showlegend":true,"textposition":"auto","x":["BTM","Banashankari","Banaswadi","Bellandur","Electronic City","HSR ...

# %%
order_online.name.unique().shape
# Out:
# (4418,)

# %%
plt.rcParams['figure.figsize'] = [4,3]
g=sns.histplot(
    df, x="cost", y="online_order",hue="online_order",legend=False,

)
g.set_yticklabels(["YES","NO"])

#sns.histplot(penguins, x="bill_depth_mm", y="body_mass_g", hue="species")
# Out:
# <ipython-input-20-05a132d39e67>:6: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# [Text(0, 0, 'YES'), Text(0, 1, 'NO')]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# # sample 3000

# %%
from tqdm import tqdm
all_ratings = []
for name, ratings in tqdm(zip(order_online['name'][:3000], order_online['reviews_list'][:3000])):
    ratings = eval(ratings)
    for score, doc in ratings:
        if score:
            score = score.strip("Rated").strip()
            doc = doc.strip('RATED').strip()
            score = float(score)
            all_ratings.append([name, score, doc])
# Out:
# 3000it [00:00, 3941.32it/s]

# %% [markdown]
# #Sample 10k size

# %%
sample_order=order_online.sample(n=10000)

# %%
all_ratings = []
from tqdm.notebook import tqdm

for name,ratings in tqdm(zip(order_online['name'],order_online['reviews_list'])):
    ratings = eval(ratings)
    for score, doc in ratings:
        if score:
            score = score.strip("Rated").strip()
            doc = doc.strip('RATED').strip()
            score = float(score)
            all_ratings.append([name,score, doc])
# Out:
# 0it [00:00, ?it/s]

# %%
import re
rating_df=pd.DataFrame(all_ratings,columns=['name','rating','review'])
rating_df['review']=rating_df['review'].apply(lambda x : re.sub('[^a-zA-Z0-9\s]',"",x))

# %%
rating_df
# Out:
#                         name  rating  \
# 0                      Jalsa     4.0
# 1                      Jalsa     4.0
# 2                      Jalsa     2.0
# 3                      Jalsa     4.0
# 4                      Jalsa     5.0
# ...                      ...     ...
# 831119  Oliver's Pub & Diner     2.0
# 831120  Oliver's Pub & Diner     3.0
# 831121  Oliver's Pub & Diner     4.0
# 831122    Izakaya Gastro Pub     3.0
# 831123    Izakaya Gastro Pub     4.0
#
#                                                    review
# 0       A beautiful place to dine inThe interiors take...
# 1       I was here for dinner with my family on a week...
# 2       Its a restaurant near to Banashankari BDA Me a...
# 3       We went here on a weekend and one of us had th...
# 4       The best thing about the place is its ambiance...
# ...                                                   ...
# 831119  Pathetic presentation of the dishes the plate ...
# 831120  Went there on a Friday eve They were out of al...
# 831121  Olivers Pub is a decent place with a good ambi...
# 831122  Nice place to hangout with kids It is in one p...
# 831123  This pub is available near the bowling alley a...
#
# [831124 rows x 3 columns]

# %%
rating_df.to_csv("Ratings.csv")
rating_df.head(2)
# Out:
#     name  rating                                             review
# 0  Jalsa     4.0  A beautiful place to dine inThe interiors take...
# 1  Jalsa     4.0  I was here for dinner with my family on a week...

# %%
stops=stopwords.words('english')
lem=WordNetLemmatizer()
corpus=' '.join(lem.lemmatize(x) for x in rating_df[rating_df['sent']==1]['review'][:3000] if x not in stops)
tokens=word_tokenize(corpus)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
rating_df['sent']=rating_df['rating'].apply(lambda x: 1 if int(x)>2.5 else 0)

# %%
# Model Parameters
max_features = 3000       # Vocabulary size
embed_dim = 64            # Embedding dimension
lstm_out = 64             # Output dimension of LSTM layer
batch_size = 128          # Number of samples per gradient update
epochs = 5               # Number of epochs for training

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

max_features = 3000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(rating_df['review'].values)
X = tokenizer.texts_to_sequences(rating_df['review'].values)
X = pad_sequences(X)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
embed_dim = 32
lstm_out = 32

model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = X.shape[1]))
#model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2,activation='softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 195, 32)             │          96,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 104,386 (407.76 KB)
#  Trainable params: 104,386 (407.76 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
Y = pd.get_dummies(rating_df['sent'].astype(int)).values
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.33, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (556853, 195) (556853, 2)
# (274271, 195) (274271, 2)

# %%
batch_size = 3200
model.fit(X_train, Y_train, epochs = 5, batch_size=batch_size)
# Out:
# Epoch 1/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 406s 2s/step - accuracy: 0.8296 - loss: 0.3994
# Epoch 2/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 489s 3s/step - accuracy: 0.9346 - loss: 0.1685
# Epoch 3/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.9453 - loss: 0.1432
# Epoch 4/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 434s 2s/step - accuracy: 0.9514 - loss: 0.1272
# Epoch 5/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 438s 2s/step - accuracy: 0.9549 - loss: 0.1188

# %%
import pickle

with open('/content/lstm_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# !pip install joblib
import joblib
# Assuming 'model' is your trained model
joblib.dump(model, 'lstm_model.pkl')  # Save the model

# Later or in a different script, load the model
loaded_model = joblib.load('lstm_model.pkl')
loaded_model
# Out:
# <Sequential name=sequential_2, built=True>

# %%
validation_size = 1500

X_validate = X_test[-validation_size:]
Y_validate = Y_test[-validation_size:]
X_test = X_test[:-validation_size]
Y_test = Y_test[:-validation_size]
score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 2120/2120 - 108s - 51ms/step - accuracy: 0.9766 - loss: 0.0688
# score: 0.07
# acc: 0.98

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SpatialDropout1D, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

max_features = 3000
embed_dim = 32  # Lowered embedding dimension for memory efficiency
lstm_out = 32  # Lowered LSTM units
batch_size = 128  # Reduced batch size for memory constraints
epochs = 5

model = Sequential()
model.add(Embedding(max_features, embed_dim, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(lstm_out, dropout=0.1, recurrent_dropout=0.1))
model.add(Dense(2, activation='softmax'))

# Compile with a slightly higher learning rate
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Early stopping to prevent overtraining and reduce total time
early_stopping = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

# Train the model
model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, Y_test), callbacks=[early_stopping])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/5
# 4351/4351 ━━━━━━━━━━━━━━━━━━━━ 739s 168ms/step - accuracy: 0.9195 - loss: 0.2006 - val_accuracy: 0.9576 - val_loss: 0.1139
# Epoch 2/5
# 4351/4351 ━━━━━━━━━━━━━━━━━━━━ 697s 158ms/step - accuracy: 0.9592 - loss: 0.1098 - val_accuracy: 0.9670 - val_loss: 0.0913
# Epoch 3/5
# 4351/4351 ━━━━━━━━━━━━━━━━━━━━ 799s 171ms/step - accuracy: 0.9663 - loss: 0.0916 - val_accuracy: 0.9706 - val_loss: 0.0843
# Epoch 4/5
# 4351/4351 ━━━━━━━━━━━━━━━━━━━━ 688s 158ms/step - accuracy: 0.9701 - loss: 0.0819 - val_accuracy: 0.9747 - val_loss: 0.0730
# Epoch 5/5
# 4351/4351 ━━━━━━━━━━━━━━━━━━━━ 746s 159ms/step - accuracy: 0.9728 - loss: 0.0750 - val_accuracy: 0.9766 - val_loss: 0.0688

# %%
# Assuming 'model' is your trained model
joblib.dump(model, 'lstm_model01.pkl')  # Save the model

# Later or in a different script, load the model
loaded_model = joblib.load('lstm_model01.pkl')

# %%
import joblib
# Load the model from the pickle file
loaded_model = joblib.load('lstm_model01.pkl')
loaded_model
